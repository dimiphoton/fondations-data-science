# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import argopy  
import seaborn as sns
from argopy import DataFetcher as ArgoDataFetcher
argo_loader = ArgoDataFetcher()

# %%
ds = argo_loader.region([-75, -45, 20, 30, 0, 10, '2011-01-01', '2011-06']).to_xarray()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6364\830898313.py in <module>
# ----> 1 ds = argo_loader.region([-75, -45, 20, 30, 0, 10, '2011-01-01', '2011-06']).to_xarray()
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\fetchers.py in to_xarray(self, **kwargs)
#     424                 % ",".join(self.Fetchers.keys())
#     425             )
# --> 426         xds = self.fetcher.to_xarray(**kwargs)
#     427         xds = self.postproccessor(xds)
#     428
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\data_fetchers\erddap_data.py in to_xarray(self, errors)
#     456             if len(self.uri) == 1:
#     457                 try:
# --> 458                     ds = self.fs.open_dataset(self.uri[0])
#     459                 except ClientResponseError as e:
#     460                     raise ErddapServerError(e.message)
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\stores\filesystems.py in open_dataset(self, url, *args, **kwargs)
#     424         """
#     425         try:
# --> 426             data = self.fs.cat_file(url)
#     427         except aiohttp.ClientResponseError as e:
#     428             if e.status == 413:
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in wrapper(*args, **kwargs)
#     109     def wrapper(*args, **kwargs):
#     110         self = obj or args[0]
# --> 111         return sync(self.loop, func, *args, **kwargs)
#     112
#     113     return wrapper
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      94         raise FSTimeoutError from return_result
#      95     elif isinstance(return_result, BaseException):
# ---> 96         raise return_result
#      97     else:
#      98         return return_result
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in _runner(event, coro, result, timeout)
#      51         coro = asyncio.wait_for(coro, timeout=timeout)
#      52     try:
# ---> 53         result[0] = await coro
#      54     except Exception as ex:
#      55         result[0] = ex
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\implementations\http.py in _cat_file(self, url, start, end, **kwargs)
#     226         async with session.get(self.encode_url(url), **kw) as r:
#     227             out = await r.read()
# --> 228             self._raise_not_found_for_status(r, url)
#     229         return out
#     230
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\implementations\http.py in _raise_not_found_for_status(self, response, url)
#     208         """
#     209         if response.status == 404:
# --> 210             raise FileNotFoundError(url)
#     211         response.raise_for_status()
#     212
#
# FileNotFoundError: https://erddap.ifremer.fr/erddap/tabledap/ArgoFloats.nc?data_mode,latitude,longitude,position_qc,time,time_qc,direction,platform_number,cycle_number,config_mission_number,vertical_sampling_scheme,pres,temp,psal,pres_qc,temp_qc,psal_qc,pres_adjusted,temp_adjusted,psal_adjusted,pres_adjusted_qc,temp_adjusted_qc,psal_adjusted_qc,pres_adjusted_error,temp_adjusted_error,psal_adjusted_error&longitude>=-75&longitude<=-45&latitude>=20&latitude<=30&pres>=0&pres<=10&time>=1293840000.0&time<=1306886400.0&distinct()&orderBy("time,pres")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6364\2571490180.py in <module>
# ----> 1 ds2.to_xarray()
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\fetchers.py in to_xarray(self, **kwargs)
#     424                 % ",".join(self.Fetchers.keys())
#     425             )
# --> 426         xds = self.fetcher.to_xarray(**kwargs)
#     427         xds = self.postproccessor(xds)
#     428
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\data_fetchers\erddap_data.py in to_xarray(self, errors)
#     456             if len(self.uri) == 1:
#     457                 try:
# --> 458                     ds = self.fs.open_dataset(self.uri[0])
#     459                 except ClientResponseError as e:
#     460                     raise ErddapServerError(e.message)
#
# c:\Users\DimiP\miniconda3\lib\site-packages\argopy\stores\filesystems.py in open_dataset(self, url, *args, **kwargs)
#     424         """
#     425         try:
# --> 426             data = self.fs.cat_file(url)
#     427         except aiohttp.ClientResponseError as e:
#     428             if e.status == 413:
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in wrapper(*args, **kwargs)
#     109     def wrapper(*args, **kwargs):
#     110         self = obj or args[0]
# --> 111         return sync(self.loop, func, *args, **kwargs)
#     112
#     113     return wrapper
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      94         raise FSTimeoutError from return_result
#      95     elif isinstance(return_result, BaseException):
# ---> 96         raise return_result
#      97     else:
#      98         return return_result
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\asyn.py in _runner(event, coro, result, timeout)
#      51         coro = asyncio.wait_for(coro, timeout=timeout)
#      52     try:
# ---> 53         result[0] = await coro
#      54     except Exception as ex:
#      55         result[0] = ex
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\implementations\http.py in _cat_file(self, url, start, end, **kwargs)
#     226         async with session.get(self.encode_url(url), **kw) as r:
#     227             out = await r.read()
# --> 228             self._raise_not_found_for_status(r, url)
#     229         return out
#     230
#
# c:\Users\DimiP\miniconda3\lib\site-packages\fsspec\implementations\http.py in _raise_not_found_for_status(self, response, url)
#     208         """
#     209         if response.status == 404:
# --> 210             raise FileNotFoundError(url)
#     211         response.raise_for_status()
#     212
#
# FileNotFoundError: https://erddap.ifremer.fr/erddap/tabledap/ArgoFloats.nc?data_mode,latitude,longitude,position_qc,time,time_qc,direction,platform_number,cycle_number,config_mission_number,vertical_sampling_scheme,pres,temp,psal,pres_qc,temp_qc,psal_qc,pres_adjusted,temp_adjusted,psal_adjusted,pres_adjusted_qc,temp_adjusted_qc,psal_adjusted_qc,pres_adjusted_error,temp_adjusted_error,psal_adjusted_error&longitude>=-50&longitude<=0&latitude>=45&latitude<=50&pres>=0&pres<=10&time>=1609459200.0&time<=1640995200.0&distinct()&orderBy("time,pres")
